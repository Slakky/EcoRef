# %%
phenotypes.df <- read.table(file = '/home/claudio/nas/phenotypic_data.tsv', sep = "\t", header = TRUE)

# %%
df.1 <- subset(phenotypes.df, select = -c(corrected.p.values, growth.defect.phenotype))

# %%
colnames(df.1)[colnames(df.1) == "strain"] <- 'samples'
colnames(df.1)[colnames(df.1) == "s.scores"] <- 'pheno'

# %%
samples_list <- as.list(levels(unique(df.1$condition)))

# %%
for (env in samples_list){
    df.2 <- df.1[df.1$condition == unlist(env),]
    df.3 <- subset(df.2, select = -condition)
    write.table(df.3, file = sprintf('/home/claudio/nas/phenotypes/%s.tsv', unlist(env)), row.names = FALSE, col.names = TRUE, sep='\t', quote = FALSE)
}

# %%
df.1[df.1$condition == unlist(samples_list[1]),]
# Out:
#     condition samples  pheno
# 1   A22.0P5   ATC14028  0.46185285
# 2   A22.0P5   LT2       0.63486877
# 3   A22.0P5   NT12001   0.97303512
# 4   A22.0P5   NT12002   0.99304433
# 5   A22.0P5   NT12003  -0.04349600
# 6   A22.0P5   NT12004   0.53946922
# 7   A22.0P5   NT12005   0.25692086
# 8   A22.0P5   NT12007   0.78770380
# 9   A22.0P5   NT12008   0.65042755
# 10  A22.0P5   NT12009   1.32529355
# 11  A22.0P5   NT12010   4.08396545
# 12  A22.0P5   NT12011   0.38079759
# 13  A22.0P5   NT12012   0.90095332
# 14  A22.0P5   NT12013   0.84342036
# 15  A22.0P5   NT12014   1.17967544
# 16  A22.0P5   NT12015  -0.11256492
# 17  A22.0P5   NT12016   0.09524642
# 18  A22.0P5   NT12017   0.50941831
# 19  A22.0P5   NT12018  -0.41237295
# 20  A22.0P5   NT12019  -0.28307611
# 21  A22.0P5   NT12020  -0.37133505
# 22  A22.0P5   NT12021  -0.20832956
# 23  A22.0P5   NT12022  -0.14079994
# 24  A22.0P5   NT12023  -0.23602411
# 25  A22.0P5   NT12024   0.34107908
# 26  A22.0P5   NT12025  -0.73401986
# 27  A22.0P5   NT12026  -0.31279055
# 28  A22.0P5   NT12027  -0.81649890
# 29  A22.0P5   NT12028  -0.09733785
# 30  A22.0P5   NT12029  -0.65769958
# ... ...       ...      ...
# 839 A22.0P5   NT12869  -3.3581820
# 840 A22.0P5   NT12870  -0.1890463
# 841 A22.0P5   NT12871  -0.2519798
# 842 A22.0P5   NT12872  -0.7214040
# 843 A22.0P5   NT12873  -0.4122532
# 844 A22.0P5   NT12874   0.5986231
# 845 A22.0P5   NT12875   0.4746086
# 846 A22.0P5   NT12876  -0.7431380
# 847 A22.0P5   NT12878  -0.4068214
# 848 A22.0P5   NT12879   0.4506899
# 849 A22.0P5   NT12880  -0.7503761
# 850 A22.0P5   NT12883  -4.9195823
# 851 A22.0P5   NT12885  -0.2558161
# 852 A22.0P5   NT12886  -0.5359302
# 853 A22.0P5   NT12887  -1.5584123
# 854 A22.0P5   NT12888  -2.8880848
# 855 A22.0P5   NT12890   0.1326737
# 856 A22.0P5   NT12892  -0.1492234
# 857 A22.0P5   NT12893  -1.6574919
# 858 A22.0P5   NT12894  -0.6819626
# 859 A22.0P5   NT12895  -0.4666763
# 860 A22.0P5   NT12896   0.9774241
# 861 A22.0P5   NT12897  -0.8658988
# 862 A22.0P5   NT12901  -1.1515766
# 863 A22.0P5   NT12902  -0.7723967
# 864 A22.0P5   NT12903  -0.5750414
# 865 A22.0P5   NT12904  -0.7590539
# 866 A22.0P5   NT12905  -3.6138190
# 867 A22.0P5   NT12906   1.0632928
# 868 A22.0P5   NT12907  -1.3272642

# %%
df.1$samples == 'A22.0P5'

# %%
for (i in as.list(levels(unique(df.1$condition)))){
    df.2 <- df.1[i,1]
    print(df.2)
}
